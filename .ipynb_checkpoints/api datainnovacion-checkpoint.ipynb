# %%
import requests
import pandas as pd

# %%
#sacando los datos de la api 
url = 'https://datainnovacion.cl/api/v1/proyectos'
token_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvZGF0YUlubm92YXRpb24uY2wiLCJuYW1lIjoicHVibGljIGFwaUtleSJ9.Ofu3LI0z8uCNYTbZyXd9BeY0sWIDt2NzUBwnHxTtdsA'
r = requests.get(url, headers={'Authorization':token_auth})
df=pd.json_normalize(r.json(),record_path='data')
df
# Out:
#           codigo                     foco_apoyo  \
# 0     09AAP-6740                      Renuévate
# 1     09AAP-6741                      Renuévate
# 2     09AAP-7335                      Renuévate
# 3     09ACS-7457          Desarrolla innovación
# 4     09ANT-7090            Consolida y Expande
# ...          ...                            ...
# 8212      PI-998  Desarrolla innovación con I+D
# 8213    PI-99869  Desarrolla innovación con I+D
# 8214    PI-99871  Desarrolla innovación con I+D
# 8215    PI-99872  Desarrolla innovación con I+D
# 8216      PI-999  Desarrolla innovación con I+D
#
#                                            instrumento rut_beneficiario  \
# 0     Apoyo A La Atracción De Profesionales Y Técnicos        772954409
# 1     Apoyo A La Atracción De Profesionales Y Técnicos        768322201
# 2     Apoyo A La Atracción De Profesionales Y Técnicos        965328009
# 3                    Apoyo Elaboración Capital Semilla        966913304
# ...
