# %%
import pandas as pd

# %%
df = pd.read_excel('Cantidad-de-Personas-por-Sexo-y-Edad.xlsx', sheet_name='REGIONES')
df
# Out:
#      Unnamed: 0 Unnamed: 1                            Unnamed: 2  \
# 0           NaN      ORDEN                         NOMBRE REGIÓN
# 1           NaN          0                                  PAÍS
# 2           NaN          1                                  PAÍS
# 3           NaN          2                                  PAÍS
# 4           NaN          3                                  PAÍS
# ..          ...        ...                                   ...
# 348         NaN        347  MAGALLANES Y DE LA ANTÁRTICA CHILENA
# 349         NaN        348  MAGALLANES Y DE LA ANTÁRTICA CHILENA
# 350         NaN        349  MAGALLANES Y DE LA ANTÁRTICA CHILENA
# 351         NaN        350  MAGALLANES Y DE LA ANTÁRTICA CHILENA
# 352         NaN        351  MAGALLANES Y DE LA ANTÁRTICA CHILENA
#
#         Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0    Código Región        Edad    Hombres    Mujeres      TOTAL
# ...

# %%
df.columns = df.iloc[0]
df.drop(labels=0, axis=0, inplace=True)
df.drop(df.columns[1], axis=1, inplace=True)
df
# Out:
# 0    NaN                         NOMBRE REGIÓN Código Región        Edad  \
# 1    NaN                                  PAÍS          PAÍS  Total País
# 2    NaN                                  PAÍS          PAÍS       0 a 4
# 3    NaN                                  PAÍS          PAÍS       5 a 9
# 4    NaN                                  PAÍS          PAÍS     10 a 14
# 5    NaN                                  PAÍS          PAÍS     15 a 19
# ..   ...                                   ...           ...         ...
# 348  NaN  MAGALLANES Y DE LA ANTÁRTICA CHILENA            12     80 a 84
# 349  NaN  MAGALLANES Y DE LA ANTÁRTICA CHILENA            12     85 a 89
# 350  NaN  MAGALLANES Y DE LA ANTÁRTICA CHILENA            12     90 a 94
# 351  NaN  MAGALLANES Y DE LA ANTÁRTICA CHILENA            12     95 a 99
# 352  NaN  MAGALLANES Y DE LA ANTÁRTICA CHILENA            12   100 o más
#
# 0    Hombres  Mujeres     TOTAL
# 1    8601989  8972014  17574003
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [nan, NOMBRE REGIÓN, Código Región, Edad, Hombres, Mujeres, TOTAL]
# Index: []
